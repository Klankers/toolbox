# %% [markdown]
# # Glider Toolbox Demo Notebook

# %% [markdown]
# ### Using a Pre-existing config file for a complete pipeline run
#
# Note: Currently these imports are local references. In the future the toolbox will be an installable package through pip.

# %%
# add toolbox to src (THIS WILL NOT BE REQUIRED ONCE DEPLOYED)
import sys
from pathlib import Path
src_path = Path("../../src").resolve()

if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

# %% [markdown]
# ### Pipeline Overview

# %%
# from toolbox.pipeline import Pipeline
# pipeline = Pipeline(   
#     "../configs/example_config_nelson.yaml")
# pipeline.run()

# %% [markdown]
# #### Building the pipeline one step at a time

# %%
# pipeline2 = Pipeline()

# class myCustomStep:
#     def __init__(self, param1, param2):
#         self.param1 = param1
#         self.param2 = param2

#     def run(self, data):
#         # Custom processing logic here
#         print(f"Running custom step with {self.param1} and {self.param2}")
#         return data  # Return processed data

# # add load step
# pipeline2.add_step(
#     "Load OG1",
#     parameters={
#         "file_path": "../../examples/data/OG1/Churchill_647_R.nc",  # Path to the input NetCDF file
#         "add_meta": False, # Add metadata to the data
#         "add_depth": True, # Add depth information to the data
#         "add_elapsed_time": False,
#         "lat_label": "DEPLOYMENT_LATITUDE"},
#     diagnostics=False,
#     run_immediately=True )# can run immediately upon creation

# # add export step
# pipeline2.add_step(
#     "Data Export",
#     parameters={
#         "export_format": "netcdf",  # Define the export format (e.g., OG1, CSV, etc.)
#         "output_path": "../../examples/data/OG1/exported_Churchill_647_R.nc"},
#     diagnostics=False,
#     run_immediately=False )# or run at a future time
# # run last step
# pipeline2.run_last_step()

# %%
# conf = pipeline2.export_config("../../examples/data/OG1/Churchill_647_R_CONFIG.yaml")  # Export the pipeline configuration to a YAML file
# conf

# %% [markdown]
# # Running Multiple Pipelines
#
# ```python

# %%
### Running multiple pipelines using the PipelineManager class
from toolbox.pipeline_manager import PipelineManager
mngr = PipelineManager()
mngr.load_mission_control("../configs/MissionControl.yaml")  # Load the mission control configuration
# This is currently set up to import data, run profiles, and export data for Doombar and Churchill sources.
mngr.run_all()  # Run all pipelines defined in the mission control configuration
# Out:
# [Discovery] Scanning for step modules in C:\Users\ddab1n24\OneDrive - University of Southampton\Documents\PhD\RISC\toolbox\src\toolbox\steps\custom
# [Discovery] Importing step module: toolbox.steps.custom.apply_qc
# [Discovery] Importing step module: toolbox.steps.custom.blank_step
# [Discovery] Importing step module: toolbox.steps.custom.calibration
# [Discovery] Importing step module: toolbox.steps.custom.derive_ctd
# [Discovery] Importing step module: toolbox.steps.custom.export
# [Discovery] Importing step module: toolbox.steps.custom.find_profiles
# [Discovery] Importing step module: toolbox.steps.custom.gen_data
# [Discovery] Importing step module: toolbox.steps.custom.interpolate_data
# [Discovery] Importing step module: toolbox.steps.custom.load_data
# [Discovery] Importing step module: toolbox.steps.custom.profile_direction
# [Discovery] Importing step module: toolbox.steps.custom.qc.archive
# [Discovery] Importing step module: toolbox.steps.custom.qc.blank_test
# [Discovery] Importing step module: toolbox.steps.custom.qc.flag_full_profile
# [Discovery] Importing step module: toolbox.steps.custom.qc.impossible_date_test
# [Discovery] Importing step module: toolbox.steps.custom.qc.impossible_location_test
# [Discovery] Importing step module: toolbox.steps.custom.qc.impossible_speed_test
# [Discovery] Importing step module: toolbox.steps.custom.qc.par_irregularity_test
# [Discovery] Importing step module: toolbox.steps.custom.qc.position_on_land_test
# [Discovery] Importing step module: toolbox.steps.custom.qc.pressure_range_test
# [Discovery] Importing step module: toolbox.steps.custom.qc.range_test
# [Discovery] Importing step module: toolbox.steps.custom.qc.spike_test
# [Discovery] Importing step module: toolbox.steps.custom.qc.stuck_value_test
# [Discovery] Importing step module: toolbox.steps.custom.qc.valid_profile_test
# [Discovery] Importing step module: toolbox.steps.custom.variables.bbp
# [Discovery] Importing step module: toolbox.steps.custom.variables.chla
# [Discovery] Importing step module: toolbox.steps.custom.variables.salinity
# [Discovery] Registered step: Apply QC
# [Discovery] Registered step: Blank Step
# [Discovery] Registered step: Derive CTD
# [Discovery] Registered step: Data Export
# [Discovery] Registered step: Find Profiles
# [Discovery] Registered step: Generate Data
# [Discovery] Registered step: Interpolate Data
# [Discovery] Registered step: Load OG1
# [Discovery] Registered step: Find Profile Direction
# [Discovery] Registered step: BBP from Beta
# [Discovery] Registered step: Isolate BBP Spikes
# [Discovery] Registered step: Chla Deep Correction
# [Discovery] Registered step: Chla Quenching Correction
# [Discovery] Registered step: Salinity Adjustment
# [Discovery] Registered QC test:
# [Discovery] Registered QC test: flag full profile
# [Discovery] Registered QC test: impossible date test
# [Discovery] Registered QC test: impossible location test
# [Discovery] Registered QC test: impossible speed test
# [Discovery] Registered QC test: PAR irregularity test
# [Discovery] Registered QC test: position on land test
# [Discovery] Registered QC test: pressure range test
# [Discovery] Registered QC test: range test
# [Discovery] Registered QC test: spike test
# [Discovery] Registered QC test: stuck value test
# [Discovery] Registered QC test: valid profile test
# target_ds_raw shape: FrozenMappingWarningOnValuesAccess({'N_MEASUREMENTS': 10})
# ds shape: FrozenMappingWarningOnValuesAccess({'N_MEASUREMENTS': 8})
#
# Combined shape: FrozenMappingWarningOnValuesAccess({'N_MEASUREMENTS': 18})
# Combined N_MEASUREMENTS length: 18
# Step 'Load OG1' added successfully!
# Step 'Derive CTD' added successfully!
# Step 'Find Profiles' added successfully!
# [Pipeline Manager] Pipeline 'Churchill' added from ../../examples/configs/example_config_churchill.yaml.
# Step 'Load OG1' added successfully!
# Step 'Derive CTD' added successfully!
# Step 'Find Profiles' added successfully!
# [Pipeline Manager] Pipeline 'Doombar' added from ../../examples/configs/example_config_doombar.yaml.
# Step 'Load OG1' added successfully!
# Step 'Derive CTD' added successfully!
# Step 'Find Profiles' added successfully!
# [Pipeline Manager] Pipeline 'Nelson' added from ../../examples/configs/example_config_nelson.yaml.
# Step 'Load OG1' added successfully!
# Step 'Derive CTD' added successfully!
# Step 'Find Profiles' added successfully!
# [Pipeline Manager] Pipeline 'Cabot' added from ../../examples/configs/example_config_cabot.yaml.
# ####################
# Running pipeline: Churchill
# Executing: Load OG1
# [Derive CTD] Data found in context.
# Executing: Derive CTD
# [Derive CTD] Processing CTD...
# [Derive CTD] Deriving DEPTH...
# [Derive CTD] Deriving PRAC_SALINITY...
# [Derive CTD] Deriving ABS_SALINITY...
# [Derive CTD] Deriving CONS_TEMP...
# [Derive CTD] Deriving DENSITY...
# [Find Profiles] Data found in context.
# Executing: Find Profiles
# [Find Profiles] Attempting to designate profile numbers
# ####################
# Running pipeline: Doombar
# Executing: Load OG1
# [Derive CTD] Data found in context.
# Executing: Derive CTD
# [Derive CTD] Processing CTD...
# [Derive CTD] Deriving DEPTH...
# [Derive CTD] Deriving PRAC_SALINITY...
# [Derive CTD] Deriving ABS_SALINITY...
# [Derive CTD] Deriving CONS_TEMP...
# [Derive CTD] Deriving DENSITY...
# [Find Profiles] Data found in context.
# Executing: Find Profiles
# [Find Profiles] Attempting to designate profile numbers
# ####################
# Running pipeline: Nelson
# Executing: Load OG1
# [Derive CTD] Data found in context.
# Executing: Derive CTD
# [Derive CTD] Processing CTD...
# [Derive CTD] Deriving DEPTH...
# [Derive CTD] Deriving PRAC_SALINITY...
# [Derive CTD] Deriving ABS_SALINITY...
# [Derive CTD] Deriving CONS_TEMP...
# [Derive CTD] Deriving DENSITY...
# [Find Profiles] Data found in context.
# Executing: Find Profiles
# [Find Profiles] Attempting to designate profile numbers
# ####################
# Running pipeline: Cabot
# Executing: Load OG1
# [Derive CTD] Data found in context.
# Executing: Derive CTD
# [Derive CTD] Processing CTD...
# [Derive CTD] Deriving DEPTH...
# [Derive CTD] Deriving PRAC_SALINITY...
# [Derive CTD] Deriving ABS_SALINITY...
# [Derive CTD] Deriving CONS_TEMP...
# [Derive CTD] Deriving DENSITY...
# [Find Profiles] Data found in context.
# Executing: Find Profiles
# [Find Profiles] Attempting to designate profile numbers
# ####################
# All pipelines executed successfully.
# Contexts cached: dict_keys(['Churchill', 'Doombar', 'Nelson', 'Cabot'])
# ####################

# %%
mngr.summarise_all_profiles()

# %%
mngr.preview_alignment("Cabot")  # Align data to the target source (e.g., Doombar)

# %%
mngr.fit_and_save_to_target("Cabot")  # Fit data to the target source (e.g., Doombar)

# %%
mngr.validate_with_device(["Churchill", "Cabot"])

# %%
mngr.fit_to_device()
# Out:
# [Fit→Device] Using device='CTD DY180', variables=['CNDC', 'TEMP']
# [Fit→Device] R² thresholds: {'CNDC': 0.95, 'TEMP': 0.9}
# [Pipeline Manager] Interpolating missing DEPTH values by PROFILE_NUMBER...
# [Device] Loaded 15 files → 7939 rows, 15 profiles.
# Variables: n_unity, nrows1, ncols1, pad_variable, altimeter, asal1, asal2, cond1, cond2, fluor, latitude, longitude, oxygen1, oxygen2, par, potemp1, potemp2, press, psal1, psal2, scan, temp1, temp2, time, transmittance, turbidity, TEMP, CNDC, psal, potemp, asal, oxygen, depth, TIME, LATITUDE, LONGITUDE, DEPTH
# [Validation] Matched 46 pairs with CTD DY180.
# [Pipeline Manager] Interpolating missing DEPTH values by PROFILE_NUMBER...
# [Filter] Aggregated case: 4986 → 44 profiles retained.
# [Filter] Resulting dims: FrozenMappingWarningOnValuesAccess({'PROFILE_NUMBER': 44, 'DEPTH_bin': 216})
# [Filter] Aggregated case: 15 → 2 profiles retained.
# [Filter] Resulting dims: FrozenMappingWarningOnValuesAccess({'PROFILE_NUMBER': 2, 'DEPTH_bin': 439})
# [Validation] Dropped 2 target profiles with no aggregated data.
# [Validation] Merged data has 44 pairs.
# [Fit→Device] CNDC: device ≈ 10.02·target + -0.02112 (R²=0.992, N=5700)
# [Fit→Device] TEMP: device ≈ 0.9963·target + 0.08155 (R²=0.994, N=5700)

# %%
mngr.apply_adjustment(
    "Cabot", 
    {
        "TEMP": {
            "slope": 0.9963,
            "intercept": 0.08155,
            "n": 5700
        },
        "CNDC": {
            "slope": 10.02,
            "intercept": -0.02112,
            "n": 5700
        }
    }
)
# Out:
# {'fits': {'TEMP': {'slope': 1.007, 'intercept': -0.01955, 'n': 2364},
#   'CNDC': {'slope': 10.11, 'intercept': -0.3846, 'n': 2364}},
#  'device_name': 'CTD DY180'}

# %%
mngr.save(r"C:\Users\ddab1n24\OneDrive - University of Southampton\Documents\PhD\RISC\toolbox\examples\notebooks")
# Out:
# Saving raw outputs.
# Saving processed outputs.

# %%
import xarray as xr
test = xr.load_dataset(r"C:\Users\ddab1n24\OneDrive - University of Southampton\Documents\PhD\RISC\toolbox\examples\notebooks\Churchill_Nelson_Doombar_Cabot_processed.nc")
test
# Out:
# <xarray.Dataset> Size: 9MB
# Dimensions:         (PROFILE_NUMBER: 4986, DEPTH_bin: 216)
# Coordinates:
#   * PROFILE_NUMBER  (PROFILE_NUMBER) <U15 299kB '1.0_Cabot' ... 'nan_Nelson'
#   * DEPTH_bin       (DEPTH_bin) float64 2kB -15.0 -10.0 ... 1.055e+03 1.06e+03
# Data variables:
#     median_CNDC     (PROFILE_NUMBER, DEPTH_bin) float32 4MB 0.00421 ... 3.319
#     median_TEMP     (PROFILE_NUMBER, DEPTH_bin) float32 4MB 21.19 nan ... 4.242
